# %%
BRONZE = "abfss://basecontainer@ecommprojadls.dfs.core.windows.net/bronze/orders/"
df = spark.read.parquet(BRONZE)

df.groupBy("_op").count().show()
df.groupBy("_batch_version").count().orderBy("_batch_version").show()
print("distinct keys:", df.select("order_id").distinct().count(), "of", df.count())

# %%
BRONZE = "abfss://basecontainer@ecommprojadls.dfs.core.windows.net/bronze/orders/"
df = spark.read.parquet(BRONZE)

df.groupBy("_op").count().show()
df.groupBy("_batch_version").count().orderBy("_batch_version").show()
print(df.count(), "rows /", df.select("order_id").distinct().count(), "keys")

# %%
# %sql
DESCRIBE HISTORY ecomm.silver.orders_current;

# %%
# %sql
select customer_unique_id, count(*)
from ecomm.silver.orders_current
group by customer_unique_id

# %%
# %sql
select * from ecomm.silver.orders_current
where customer_unique_id = 'dc813062e0fc23409cd255f7f53c7074'

# %%
# %sql
select * from ecomm.gold.fact_order_lifecycle
where customer_unique_id = 'dc813062e0fc23409cd255f7f53c7074'

# %%
# %sql
select * from ecomm.silver.customers_current

# %%
# %sql
SELECT COUNT(*) AS total,
       COUNT(DISTINCT customer_unique_id) AS people
FROM ecomm.gold.dim_customer;
